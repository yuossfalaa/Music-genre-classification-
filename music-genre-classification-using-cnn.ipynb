# %%
import json
import os
import math
import librosa
import numpy as np
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

DATASET_PATH = "/kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original"
JSON_PATH = "/kaggle/working/All_Data.json"
Model_PATH = "/kaggle/working/Model.keras"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.

        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:
                try:
		# load audio file
                    file_path = os.path.join(dirpath, f)
                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                    for d in range(num_segments):

                    # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                    # extract mfcc
                        mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment:{}".format(file_path, d+1))
                except:
                      print("An exception occurred")

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Processing: disco
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00031.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00089.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00079.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00030.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00060.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00082.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00038.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00006.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00075.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00066.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00023.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00034.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00078.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00098.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00004.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00094.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00054.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00074.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00017.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00053.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00005.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00045.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00047.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00084.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00020.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00012.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00073.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00000.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00072.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00033.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00096.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00037.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00092.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00087.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00025.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00083.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00021.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00040.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00002.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00036.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00052.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00063.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00080.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/disco/disco.00041.wav, segment:9
# ...
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00001.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00001.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00043.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00005.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00048.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00007.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00098.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00089.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00038.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00087.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00085.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00075.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00064.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00068.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00041.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00050.wav, segment:10
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:1
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:2
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:3
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:4
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:5
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:6
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:7
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:8
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:9
# /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/pop/pop.00032.wav, segment:10

# %%
def load_data(dataset_path):
    with open(dataset_path,"r") as fp:
        data = json.load(fp)
    x = np.array(data["mfcc"])
    y = np.array(data["labels"])
    print("Data succesfully loaded!")
    return x,y

# %%
def plot_history(history):
    fig,axs = plt.subplots(2)
    axs[0].plot(history.history["accuracy"],label="train accuracy")
    axs[0].plot(history.history["val_accuracy"],label="test accuracy")
    axs[0].set_ylabel("accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")
    
    axs[1].plot(history.history["loss"],label="train error")
    axs[1].plot(history.history["val_loss"],label="test error")
    axs[1].set_ylabel("error")    
    axs[1].set_xlabel("epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")
    
    plt.show()

# %%
def prepare_datasets(X,Y,test_size=0.25,validation_size=0.2):
    x_train,x_test,y_train,y_test=  train_test_split(X,Y,test_size=test_size)
    x_train ,x_validation,y_train,y_validation= train_test_split(x_train,y_train,test_size=validation_size)
    x_train = x_train[...,np.newaxis]
    x_validation = x_validation[...,np.newaxis]
    x_test = x_test[...,np.newaxis]
    return x_train,x_validation,x_test,y_train,y_validation,y_test

# %%
def build_model(input_shape):
    model = keras.Sequential()
    model.add(keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=input_shape,kernel_regularizer=keras.regularizers.l2(0.1)))
    model.add(keras.layers.MaxPool2D((3,3),strides=(2,2),padding='same'))
    model.add(keras.layers.BatchNormalization())
    
    model.add(keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=input_shape,kernel_regularizer=keras.regularizers.l2(0.1)))
    model.add(keras.layers.MaxPool2D((3,3),strides=(2,2),padding='same'))
    model.add(keras.layers.BatchNormalization())
    
    model.add(keras.layers.Conv2D(32,(2,2),activation='relu',input_shape=input_shape,kernel_regularizer=keras.regularizers.l2(0.1)))
    model.add(keras.layers.MaxPool2D((2,2),strides=(2,2),padding='same'))
    model.add(keras.layers.BatchNormalization())
    
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64,activation='relu',kernel_regularizer=keras.regularizers.l2(0.1)))
    model.add(keras.layers.Dropout(0.4))
    
    model.add(keras.layers.Dense(10,activation='softmax'))
    return model

# %%
x,y= load_data(JSON_PATH)
x_train,x_validation,x_test,y_train,y_validation,y_test = prepare_datasets(x,y)
input_shape = (x_train.shape[1],x_train.shape[2],x_train.shape[3])
model = build_model(input_shape)
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer,
             loss="sparse_categorical_crossentropy",
             metrics=['accuracy'])
model.summary()
history = model.fit(x_train,y_train,validation_data = ( x_validation,y_validation),batch_size = 32,epochs = 100)
model.save(Model_PATH)
test_error,test_accuracy=model.evaluate(x_test,y_test)
print('error = {}'.format(test_error))
print('accuracy = {}'.format(test_accuracy))
plot_history(history)
# Out:
# Data succesfully loaded!
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 128, 11, 32)       320
#
#  max_pooling2d_21 (MaxPooli  (None, 64, 6, 32)         0
#  ng2D)
#
#  batch_normalization_21 (Ba  (None, 64, 6, 32)         128
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 62, 4, 32)         9248
#
#  max_pooling2d_22 (MaxPooli  (None, 31, 2, 32)         0
#  ng2D)
#
#  batch_normalization_22 (Ba  (None, 31, 2, 32)         128
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 30, 1, 32)         4128
#
#  max_pooling2d_23 (MaxPooli  (None, 15, 1, 32)         0
#  ng2D)
#
#  batch_normalization_23 (Ba  (None, 15, 1, 32)         128
#  tchNormalization)
#
#  flatten_7 (Flatten)         (None, 480)               0
#
#  dense_13 (Dense)            (None, 64)                30784
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 45514 (177.79 KB)
# Trainable params: 45322 (177.04 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 188/188 [==============================] - 4s 6ms/step - loss: 18.7012 - accuracy: 0.1864 - val_loss: 16.4744 - val_accuracy: 0.2817
# Epoch 2/100
# 188/188 [==============================] - 1s 5ms/step - loss: 15.0318 - accuracy: 0.3073 - val_loss: 13.3442 - val_accuracy: 0.4099
# Epoch 3/100
# 188/188 [==============================] - 1s 5ms/step - loss: 12.2173 - accuracy: 0.3826 - val_loss: 10.8708 - val_accuracy: 0.4539
# Epoch 4/100
# 188/188 [==============================] - 1s 5ms/step - loss: 9.9628 - accuracy: 0.4231 - val_loss: 8.8718 - val_accuracy: 0.5040
# Epoch 5/100
# 188/188 [==============================] - 1s 5ms/step - loss: 8.1591 - accuracy: 0.4710 - val_loss: 7.2929 - val_accuracy: 0.5247
# Epoch 6/100
# 188/188 [==============================] - 1s 5ms/step - loss: 6.7150 - accuracy: 0.5026 - val_loss: 6.0282 - val_accuracy: 0.5701
# Epoch 7/100
# 188/188 [==============================] - 1s 5ms/step - loss: 5.5906 - accuracy: 0.5291 - val_loss: 5.0324 - val_accuracy: 0.5968
# Epoch 8/100
# 188/188 [==============================] - 1s 5ms/step - loss: 4.6842 - accuracy: 0.5555 - val_loss: 4.2574 - val_accuracy: 0.5941
# Epoch 9/100
# 188/188 [==============================] - 1s 5ms/step - loss: 3.9981 - accuracy: 0.5814 - val_loss: 3.6612 - val_accuracy: 0.6242
# Epoch 10/100
# 188/188 [==============================] - 1s 5ms/step - loss: 3.4664 - accuracy: 0.5999 - val_loss: 3.1780 - val_accuracy: 0.6449
# Epoch 11/100
# 188/188 [==============================] - 1s 5ms/step - loss: 3.0296 - accuracy: 0.6141 - val_loss: 2.8233 - val_accuracy: 0.6342
# Epoch 12/100
# 188/188 [==============================] - 1s 5ms/step - loss: 2.7093 - accuracy: 0.6268 - val_loss: 2.4880 - val_accuracy: 0.6769
# Epoch 13/100
# 188/188 [==============================] - 1s 5ms/step - loss: 2.4353 - accuracy: 0.6511 - val_loss: 2.2801 - val_accuracy: 0.6802
# Epoch 14/100
# 188/188 [==============================] - 1s 5ms/step - loss: 2.2296 - accuracy: 0.6650 - val_loss: 2.0600 - val_accuracy: 0.6862
# Epoch 15/100
# 188/188 [==============================] - 1s 5ms/step - loss: 2.0579 - accuracy: 0.6824 - val_loss: 1.9517 - val_accuracy: 0.7029
# Epoch 16/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.9159 - accuracy: 0.6964 - val_loss: 1.8387 - val_accuracy: 0.6963
# Epoch 17/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.8067 - accuracy: 0.7081 - val_loss: 1.7597 - val_accuracy: 0.7043
# Epoch 18/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.7087 - accuracy: 0.7171 - val_loss: 1.6507 - val_accuracy: 0.7049
# Epoch 19/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.6351 - accuracy: 0.7212 - val_loss: 1.5895 - val_accuracy: 0.7183
# Epoch 20/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.5506 - accuracy: 0.7354 - val_loss: 1.4970 - val_accuracy: 0.7316
# Epoch 21/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.5048 - accuracy: 0.7368 - val_loss: 1.4735 - val_accuracy: 0.7283
# Epoch 22/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.4312 - accuracy: 0.7530 - val_loss: 1.4085 - val_accuracy: 0.7330
# Epoch 23/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.3986 - accuracy: 0.7501 - val_loss: 1.4024 - val_accuracy: 0.7417
# Epoch 24/100
# 188/188 [==============================] - 1s 6ms/step - loss: 1.3392 - accuracy: 0.7738 - val_loss: 1.3851 - val_accuracy: 0.7336
# Epoch 25/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.3157 - accuracy: 0.7628 - val_loss: 1.2865 - val_accuracy: 0.7690
# Epoch 26/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.2765 - accuracy: 0.7798 - val_loss: 1.2787 - val_accuracy: 0.7603
# Epoch 27/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.2505 - accuracy: 0.7787 - val_loss: 1.3431 - val_accuracy: 0.7350
# Epoch 28/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.2139 - accuracy: 0.7850 - val_loss: 1.2183 - val_accuracy: 0.7603
# Epoch 29/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.1927 - accuracy: 0.7899 - val_loss: 1.2004 - val_accuracy: 0.7717
# Epoch 30/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.1627 - accuracy: 0.7909 - val_loss: 1.2154 - val_accuracy: 0.7477
# Epoch 31/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.1305 - accuracy: 0.7985 - val_loss: 1.2130 - val_accuracy: 0.7577
# Epoch 32/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.1047 - accuracy: 0.8040 - val_loss: 1.2409 - val_accuracy: 0.7336
# Epoch 33/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.0791 - accuracy: 0.8082 - val_loss: 1.1739 - val_accuracy: 0.7637
# Epoch 34/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.0649 - accuracy: 0.8095 - val_loss: 1.1169 - val_accuracy: 0.7810
# Epoch 35/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.0401 - accuracy: 0.8171 - val_loss: 1.0603 - val_accuracy: 0.7971
# Epoch 36/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.0202 - accuracy: 0.8216 - val_loss: 1.2144 - val_accuracy: 0.7270
# Epoch 37/100
# 188/188 [==============================] - 1s 5ms/step - loss: 1.0005 - accuracy: 0.8206 - val_loss: 1.0869 - val_accuracy: 0.7724
# Epoch 38/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.9763 - accuracy: 0.8321 - val_loss: 1.0555 - val_accuracy: 0.7897
# Epoch 39/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.9653 - accuracy: 0.8316 - val_loss: 1.0386 - val_accuracy: 0.7977
# Epoch 40/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.9739 - accuracy: 0.8224 - val_loss: 1.0545 - val_accuracy: 0.7824
# Epoch 41/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.9347 - accuracy: 0.8351 - val_loss: 1.0492 - val_accuracy: 0.7737
# Epoch 42/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.9287 - accuracy: 0.8391 - val_loss: 1.0778 - val_accuracy: 0.7750
# Epoch 43/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8997 - accuracy: 0.8489 - val_loss: 1.0920 - val_accuracy: 0.7623
# Epoch 44/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8960 - accuracy: 0.8459 - val_loss: 1.0920 - val_accuracy: 0.7583
# Epoch 45/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8909 - accuracy: 0.8449 - val_loss: 0.9454 - val_accuracy: 0.8191
# Epoch 46/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8571 - accuracy: 0.8533 - val_loss: 0.9721 - val_accuracy: 0.8044
# Epoch 47/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8488 - accuracy: 0.8566 - val_loss: 0.9459 - val_accuracy: 0.8104
# Epoch 48/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8635 - accuracy: 0.8444 - val_loss: 1.0063 - val_accuracy: 0.7744
# Epoch 49/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8319 - accuracy: 0.8583 - val_loss: 1.0127 - val_accuracy: 0.7844
# Epoch 50/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8322 - accuracy: 0.8606 - val_loss: 0.9894 - val_accuracy: 0.7710
# Epoch 51/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8024 - accuracy: 0.8660 - val_loss: 0.9625 - val_accuracy: 0.7984
# Epoch 52/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.8128 - accuracy: 0.8615 - val_loss: 0.9636 - val_accuracy: 0.7951
# Epoch 53/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7972 - accuracy: 0.8668 - val_loss: 0.9712 - val_accuracy: 0.7797
# Epoch 54/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7963 - accuracy: 0.8646 - val_loss: 0.9413 - val_accuracy: 0.8031
# Epoch 55/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7753 - accuracy: 0.8750 - val_loss: 0.9253 - val_accuracy: 0.8184
# Epoch 56/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7579 - accuracy: 0.8753 - val_loss: 0.9375 - val_accuracy: 0.8011
# Epoch 57/100
# 188/188 [==============================] - 1s 6ms/step - loss: 0.7668 - accuracy: 0.8710 - val_loss: 0.9764 - val_accuracy: 0.7891
# Epoch 58/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7580 - accuracy: 0.8688 - val_loss: 0.9051 - val_accuracy: 0.8117
# Epoch 59/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7224 - accuracy: 0.8858 - val_loss: 1.0332 - val_accuracy: 0.7630
# Epoch 60/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7228 - accuracy: 0.8848 - val_loss: 0.9610 - val_accuracy: 0.7850
# Epoch 61/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7325 - accuracy: 0.8800 - val_loss: 0.9991 - val_accuracy: 0.7750
# Epoch 62/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7181 - accuracy: 0.8852 - val_loss: 0.9442 - val_accuracy: 0.7797
# Epoch 63/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7103 - accuracy: 0.8825 - val_loss: 0.8652 - val_accuracy: 0.8251
# Epoch 64/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7053 - accuracy: 0.8855 - val_loss: 0.9880 - val_accuracy: 0.7790
# Epoch 65/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7102 - accuracy: 0.8827 - val_loss: 0.9831 - val_accuracy: 0.7777
# Epoch 66/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7033 - accuracy: 0.8792 - val_loss: 0.9247 - val_accuracy: 0.7917
# Epoch 67/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6873 - accuracy: 0.8892 - val_loss: 0.9116 - val_accuracy: 0.8057
# Epoch 68/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6775 - accuracy: 0.8895 - val_loss: 0.9223 - val_accuracy: 0.7924
# Epoch 69/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6730 - accuracy: 0.8932 - val_loss: 0.8838 - val_accuracy: 0.8097
# Epoch 70/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6732 - accuracy: 0.8863 - val_loss: 0.8719 - val_accuracy: 0.8111
# Epoch 71/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6640 - accuracy: 0.8895 - val_loss: 0.8495 - val_accuracy: 0.8291
# Epoch 72/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6568 - accuracy: 0.8957 - val_loss: 0.9843 - val_accuracy: 0.7623
# Epoch 73/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6376 - accuracy: 0.9089 - val_loss: 0.8954 - val_accuracy: 0.7884
# Epoch 74/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6356 - accuracy: 0.9045 - val_loss: 0.9388 - val_accuracy: 0.7844
# Epoch 75/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6309 - accuracy: 0.9044 - val_loss: 0.8131 - val_accuracy: 0.8344
# Epoch 76/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6263 - accuracy: 0.9049 - val_loss: 0.9343 - val_accuracy: 0.7824
# Epoch 77/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6191 - accuracy: 0.9059 - val_loss: 0.8595 - val_accuracy: 0.7997
# Epoch 78/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6212 - accuracy: 0.8993 - val_loss: 0.8228 - val_accuracy: 0.8211
# Epoch 79/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6183 - accuracy: 0.9027 - val_loss: 0.9602 - val_accuracy: 0.7750
# Epoch 80/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6112 - accuracy: 0.9077 - val_loss: 0.8843 - val_accuracy: 0.8044
# Epoch 81/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6049 - accuracy: 0.9075 - val_loss: 0.8562 - val_accuracy: 0.8077
# Epoch 82/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5894 - accuracy: 0.9135 - val_loss: 0.9802 - val_accuracy: 0.7704
# Epoch 83/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5938 - accuracy: 0.9119 - val_loss: 0.8607 - val_accuracy: 0.8044
# Epoch 84/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5853 - accuracy: 0.9135 - val_loss: 0.9016 - val_accuracy: 0.7897
# Epoch 85/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5897 - accuracy: 0.9097 - val_loss: 0.8059 - val_accuracy: 0.8304
# Epoch 86/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5740 - accuracy: 0.9189 - val_loss: 0.9328 - val_accuracy: 0.7870
# Epoch 87/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5853 - accuracy: 0.9099 - val_loss: 1.1063 - val_accuracy: 0.7230
# Epoch 88/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5618 - accuracy: 0.9190 - val_loss: 0.8458 - val_accuracy: 0.7991
# Epoch 89/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5642 - accuracy: 0.9160 - val_loss: 0.8422 - val_accuracy: 0.8084
# Epoch 90/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5593 - accuracy: 0.9224 - val_loss: 0.9144 - val_accuracy: 0.7891
# Epoch 91/100
# 188/188 [==============================] - 1s 6ms/step - loss: 0.5472 - accuracy: 0.9266 - val_loss: 0.9739 - val_accuracy: 0.7704
# Epoch 92/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5416 - accuracy: 0.9254 - val_loss: 0.8183 - val_accuracy: 0.8238
# Epoch 93/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5554 - accuracy: 0.9215 - val_loss: 0.8952 - val_accuracy: 0.8044
# Epoch 94/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5612 - accuracy: 0.9155 - val_loss: 0.9321 - val_accuracy: 0.7764
# Epoch 95/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5336 - accuracy: 0.9226 - val_loss: 0.8637 - val_accuracy: 0.7964
# Epoch 96/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5287 - accuracy: 0.9292 - val_loss: 0.9393 - val_accuracy: 0.7804
# Epoch 97/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5470 - accuracy: 0.9222 - val_loss: 0.8533 - val_accuracy: 0.7997
# Epoch 98/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5382 - accuracy: 0.9195 - val_loss: 0.9184 - val_accuracy: 0.7877
# Epoch 99/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5341 - accuracy: 0.9256 - val_loss: 0.9895 - val_accuracy: 0.7797
# Epoch 100/100
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5387 - accuracy: 0.9200 - val_loss: 0.8694 - val_accuracy: 0.7937
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8610 - accuracy: 0.7930
# error = 0.8609740138053894
# accuracy = 0.7929515242576599
