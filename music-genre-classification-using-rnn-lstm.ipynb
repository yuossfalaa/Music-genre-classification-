# %%
import json
import os
import math
import librosa
import numpy as np
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

DATASET_PATH = "/kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original"
JSON_PATH = "/kaggle/working/All_Data.json"
Model_PATH = "/kaggle/working/Model.keras"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION
# Out:
# 2024-02-07 17:11:14.872672: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-07 17:11:14.872786: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-07 17:11:15.009573: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.

        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:
                try:
		# load audio file
                    file_path = os.path.join(dirpath, f)
                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                    for d in range(num_segments):

                    # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                    # extract mfcc
                        mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                except:
                      print("An exception occurred")

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)

# %%
def load_data(dataset_path):
    with open(dataset_path,"r") as fp:
        data = json.load(fp)
    x = np.array(data["mfcc"])
    y = np.array(data["labels"])
    print("Data succesfully loaded!")
    return x,y

# %%
def plot_history(history):
    fig,axs = plt.subplots(2)
    axs[0].plot(history.history["accuracy"],label="train accuracy")
    axs[0].plot(history.history["val_accuracy"],label="test accuracy")
    axs[0].set_ylabel("accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")
    
    axs[1].plot(history.history["loss"],label="train error")
    axs[1].plot(history.history["val_loss"],label="test error")
    axs[1].set_ylabel("error")    
    axs[1].set_xlabel("epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")
    
    plt.show()

# %%
def prepare_datasets(X,Y,test_size=0.25,validation_size=0.2):
    x_train,x_test,y_train,y_test=  train_test_split(X,Y,test_size=test_size)
    x_train ,x_validation,y_train,y_validation= train_test_split(x_train,y_train,test_size=validation_size)
    return x_train,x_validation,x_test,y_train,y_validation,y_test

# %%
def build_model(input_shape):
    model = keras.Sequential()
    model.add(keras.layers.LSTM(256,input_shape=input_shape,return_sequences=True))
    model.add(keras.layers.LSTM(64))
    model.add(keras.layers.Dense(64,activation='relu'))
    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(10,activation='softmax'))
    return model

# %%
x,y= load_data(JSON_PATH)
x_train,x_validation,x_test,y_train,y_validation,y_test = prepare_datasets(x,y)
input_shape = (x_train.shape[1],x_train.shape[2])
model = build_model(input_shape)
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer,
             loss="sparse_categorical_crossentropy",
             metrics=['accuracy'])
model.summary()
history = model.fit(x_train,y_train,validation_data = ( x_validation,y_validation),batch_size = 32,epochs = 100)
model.save(Model_PATH)
test_error,test_accuracy=model.evaluate(x_test,y_test)
print('error = {}'.format(test_error))
print('accuracy = {}'.format(test_accuracy))
plot_history(history)
# Out:
# Data succesfully loaded!
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 130, 256)          276480
#
#  lstm_8 (LSTM)               (None, 64)                82176
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 363466 (1.39 MB)
# Trainable params: 363466 (1.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 188/188 [==============================] - 7s 21ms/step - loss: 2.1215 - accuracy: 0.2382 - val_loss: 1.8995 - val_accuracy: 0.3585
# Epoch 2/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.8422 - accuracy: 0.3782 - val_loss: 1.6444 - val_accuracy: 0.4419
# Epoch 3/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.6628 - accuracy: 0.4385 - val_loss: 1.4848 - val_accuracy: 0.4920
# Epoch 4/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.5286 - accuracy: 0.4874 - val_loss: 1.3745 - val_accuracy: 0.5327
# Epoch 5/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.4298 - accuracy: 0.5169 - val_loss: 1.3086 - val_accuracy: 0.5694
# Epoch 6/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.3454 - accuracy: 0.5525 - val_loss: 1.2473 - val_accuracy: 0.5821
# Epoch 7/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.2668 - accuracy: 0.5772 - val_loss: 1.1781 - val_accuracy: 0.6095
# Epoch 8/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.2164 - accuracy: 0.5942 - val_loss: 1.1904 - val_accuracy: 0.6068
# Epoch 9/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.1619 - accuracy: 0.6171 - val_loss: 1.0966 - val_accuracy: 0.6322
# Epoch 10/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.0927 - accuracy: 0.6403 - val_loss: 1.0801 - val_accuracy: 0.6348
# Epoch 11/100
# 188/188 [==============================] - 3s 17ms/step - loss: 1.0577 - accuracy: 0.6575 - val_loss: 1.0657 - val_accuracy: 0.6322
# Epoch 12/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.9948 - accuracy: 0.6775 - val_loss: 1.0715 - val_accuracy: 0.6402
# Epoch 13/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.9530 - accuracy: 0.6880 - val_loss: 0.9967 - val_accuracy: 0.6676
# Epoch 14/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.9291 - accuracy: 0.7016 - val_loss: 0.9882 - val_accuracy: 0.6696
# Epoch 15/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.8859 - accuracy: 0.7186 - val_loss: 0.9278 - val_accuracy: 0.6916
# Epoch 16/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.8510 - accuracy: 0.7306 - val_loss: 0.9313 - val_accuracy: 0.6949
# Epoch 17/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.8280 - accuracy: 0.7455 - val_loss: 0.9016 - val_accuracy: 0.7023
# Epoch 18/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.7804 - accuracy: 0.7543 - val_loss: 0.8867 - val_accuracy: 0.7076
# Epoch 19/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.7675 - accuracy: 0.7573 - val_loss: 0.8891 - val_accuracy: 0.7056
# Epoch 20/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.7266 - accuracy: 0.7773 - val_loss: 0.8918 - val_accuracy: 0.7143
# Epoch 21/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.6903 - accuracy: 0.7930 - val_loss: 0.8551 - val_accuracy: 0.7263
# Epoch 22/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.6689 - accuracy: 0.7987 - val_loss: 0.9646 - val_accuracy: 0.6862
# Epoch 23/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.6483 - accuracy: 0.8035 - val_loss: 0.8631 - val_accuracy: 0.7236
# Epoch 24/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.6147 - accuracy: 0.8186 - val_loss: 0.8700 - val_accuracy: 0.7056
# Epoch 25/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.5937 - accuracy: 0.8231 - val_loss: 0.8436 - val_accuracy: 0.7296
# Epoch 26/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.5756 - accuracy: 0.8289 - val_loss: 0.8409 - val_accuracy: 0.7276
# Epoch 27/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.5450 - accuracy: 0.8391 - val_loss: 0.8591 - val_accuracy: 0.7263
# Epoch 28/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.5184 - accuracy: 0.8439 - val_loss: 0.8181 - val_accuracy: 0.7457
# Epoch 29/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.5394 - accuracy: 0.8391 - val_loss: 0.8583 - val_accuracy: 0.7330
# Epoch 30/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.4778 - accuracy: 0.8626 - val_loss: 0.8265 - val_accuracy: 0.7550
# Epoch 31/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.4829 - accuracy: 0.8595 - val_loss: 0.8705 - val_accuracy: 0.7356
# Epoch 32/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.4875 - accuracy: 0.8610 - val_loss: 0.8266 - val_accuracy: 0.7543
# Epoch 33/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.4213 - accuracy: 0.8803 - val_loss: 0.8207 - val_accuracy: 0.7563
# Epoch 34/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.4264 - accuracy: 0.8808 - val_loss: 0.7892 - val_accuracy: 0.7590
# Epoch 35/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.4199 - accuracy: 0.8797 - val_loss: 0.7905 - val_accuracy: 0.7684
# Epoch 36/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3951 - accuracy: 0.8838 - val_loss: 0.7912 - val_accuracy: 0.7730
# Epoch 37/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3736 - accuracy: 0.8932 - val_loss: 0.8323 - val_accuracy: 0.7557
# Epoch 38/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.4090 - accuracy: 0.8775 - val_loss: 0.8150 - val_accuracy: 0.7724
# Epoch 39/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3494 - accuracy: 0.8982 - val_loss: 0.8520 - val_accuracy: 0.7523
# Epoch 40/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3892 - accuracy: 0.8913 - val_loss: 0.7988 - val_accuracy: 0.7697
# Epoch 41/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3444 - accuracy: 0.9014 - val_loss: 0.8430 - val_accuracy: 0.7597
# Epoch 42/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3150 - accuracy: 0.9097 - val_loss: 0.8274 - val_accuracy: 0.7704
# Epoch 43/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3475 - accuracy: 0.9022 - val_loss: 0.8547 - val_accuracy: 0.7697
# Epoch 44/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3373 - accuracy: 0.9055 - val_loss: 0.7985 - val_accuracy: 0.7830
# Epoch 45/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2885 - accuracy: 0.9197 - val_loss: 0.8154 - val_accuracy: 0.7824
# Epoch 46/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2683 - accuracy: 0.9281 - val_loss: 0.7828 - val_accuracy: 0.7891
# Epoch 47/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2804 - accuracy: 0.9199 - val_loss: 0.9058 - val_accuracy: 0.7730
# Epoch 48/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.2801 - accuracy: 0.9229 - val_loss: 0.8366 - val_accuracy: 0.7897
# Epoch 49/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2506 - accuracy: 0.9289 - val_loss: 0.8407 - val_accuracy: 0.7924
# Epoch 50/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.3598 - accuracy: 0.8983 - val_loss: 0.8832 - val_accuracy: 0.7697
# Epoch 51/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2789 - accuracy: 0.9187 - val_loss: 0.8677 - val_accuracy: 0.7730
# Epoch 52/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2987 - accuracy: 0.9184 - val_loss: 0.8277 - val_accuracy: 0.7817
# Epoch 53/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2471 - accuracy: 0.9291 - val_loss: 0.7749 - val_accuracy: 0.7991
# Epoch 54/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2133 - accuracy: 0.9431 - val_loss: 0.8419 - val_accuracy: 0.7850
# Epoch 55/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2274 - accuracy: 0.9387 - val_loss: 0.8691 - val_accuracy: 0.7864
# Epoch 56/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2050 - accuracy: 0.9427 - val_loss: 0.9076 - val_accuracy: 0.7870
# Epoch 57/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2608 - accuracy: 0.9254 - val_loss: 0.8536 - val_accuracy: 0.7984
# Epoch 58/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1944 - accuracy: 0.9464 - val_loss: 0.8342 - val_accuracy: 0.7924
# Epoch 59/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1959 - accuracy: 0.9466 - val_loss: 0.8611 - val_accuracy: 0.7917
# Epoch 60/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2029 - accuracy: 0.9412 - val_loss: 0.8760 - val_accuracy: 0.7991
# Epoch 61/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1944 - accuracy: 0.9446 - val_loss: 0.8549 - val_accuracy: 0.7957
# Epoch 62/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2198 - accuracy: 0.9397 - val_loss: 0.8806 - val_accuracy: 0.7944
# Epoch 63/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1970 - accuracy: 0.9429 - val_loss: 0.8535 - val_accuracy: 0.7797
# Epoch 64/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2235 - accuracy: 0.9366 - val_loss: 0.8750 - val_accuracy: 0.7977
# Epoch 65/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1593 - accuracy: 0.9588 - val_loss: 0.8533 - val_accuracy: 0.8091
# Epoch 66/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1584 - accuracy: 0.9589 - val_loss: 0.8789 - val_accuracy: 0.7964
# Epoch 67/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1669 - accuracy: 0.9549 - val_loss: 0.9003 - val_accuracy: 0.7917
# Epoch 68/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1928 - accuracy: 0.9469 - val_loss: 0.8878 - val_accuracy: 0.7991
# Epoch 69/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2209 - accuracy: 0.9364 - val_loss: 0.9536 - val_accuracy: 0.7937
# Epoch 70/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1990 - accuracy: 0.9439 - val_loss: 0.8892 - val_accuracy: 0.7917
# Epoch 71/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.2137 - accuracy: 0.9416 - val_loss: 0.9558 - val_accuracy: 0.7824
# Epoch 72/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1810 - accuracy: 0.9531 - val_loss: 0.8543 - val_accuracy: 0.8131
# Epoch 73/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1343 - accuracy: 0.9626 - val_loss: 0.9310 - val_accuracy: 0.8091
# Epoch 74/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1230 - accuracy: 0.9690 - val_loss: 0.9030 - val_accuracy: 0.8097
# Epoch 75/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1150 - accuracy: 0.9706 - val_loss: 0.9307 - val_accuracy: 0.8031
# Epoch 76/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1262 - accuracy: 0.9670 - val_loss: 1.0096 - val_accuracy: 0.7777
# Epoch 77/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1429 - accuracy: 0.9616 - val_loss: 0.9325 - val_accuracy: 0.8057
# Epoch 78/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1396 - accuracy: 0.9584 - val_loss: 0.9483 - val_accuracy: 0.7870
# Epoch 79/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1446 - accuracy: 0.9614 - val_loss: 0.9746 - val_accuracy: 0.7937
# Epoch 80/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1481 - accuracy: 0.9618 - val_loss: 0.9386 - val_accuracy: 0.7984
# Epoch 81/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1381 - accuracy: 0.9651 - val_loss: 0.9295 - val_accuracy: 0.8017
# Epoch 82/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1380 - accuracy: 0.9644 - val_loss: 0.9539 - val_accuracy: 0.7971
# Epoch 83/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1221 - accuracy: 0.9710 - val_loss: 0.9362 - val_accuracy: 0.8044
# Epoch 84/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.0924 - accuracy: 0.9751 - val_loss: 0.9090 - val_accuracy: 0.8097
# Epoch 85/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1196 - accuracy: 0.9681 - val_loss: 1.0494 - val_accuracy: 0.7850
# Epoch 86/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1283 - accuracy: 0.9670 - val_loss: 1.0185 - val_accuracy: 0.7924
# Epoch 87/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1823 - accuracy: 0.9539 - val_loss: 0.9186 - val_accuracy: 0.8031
# Epoch 88/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1323 - accuracy: 0.9613 - val_loss: 0.9399 - val_accuracy: 0.8071
# Epoch 89/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.0930 - accuracy: 0.9761 - val_loss: 0.8959 - val_accuracy: 0.8204
# Epoch 90/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.0799 - accuracy: 0.9810 - val_loss: 0.9395 - val_accuracy: 0.8171
# Epoch 91/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1201 - accuracy: 0.9710 - val_loss: 1.1007 - val_accuracy: 0.7650
# Epoch 92/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1997 - accuracy: 0.9444 - val_loss: 0.9721 - val_accuracy: 0.7937
# Epoch 93/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1358 - accuracy: 0.9638 - val_loss: 0.9282 - val_accuracy: 0.8124
# Epoch 94/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1027 - accuracy: 0.9743 - val_loss: 0.8794 - val_accuracy: 0.8284
# Epoch 95/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.0729 - accuracy: 0.9835 - val_loss: 0.9000 - val_accuracy: 0.8198
# Epoch 96/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.0709 - accuracy: 0.9828 - val_loss: 0.8987 - val_accuracy: 0.8244
# Epoch 97/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.0718 - accuracy: 0.9843 - val_loss: 1.0476 - val_accuracy: 0.8051
# Epoch 98/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1092 - accuracy: 0.9723 - val_loss: 0.9774 - val_accuracy: 0.7997
# Epoch 99/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1174 - accuracy: 0.9681 - val_loss: 0.9615 - val_accuracy: 0.8151
# Epoch 100/100
# 188/188 [==============================] - 3s 17ms/step - loss: 0.1284 - accuracy: 0.9673 - val_loss: 1.0451 - val_accuracy: 0.8031
# 79/79 [==============================] - 1s 8ms/step - loss: 1.0274 - accuracy: 0.7982
# error = 1.0274232625961304
# accuracy = 0.798157811164856
